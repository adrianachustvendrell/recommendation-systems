# %%
import pandas as pd

# %%
import pandas as pd

# Suponiendo que el archivo se llama "datos.txt"
with open("rawdata/items.txt", "r", encoding="latin-1") as file:
    # Leemos todas las líneas del archivo
    lines = file.readlines()

# Limpiamos las líneas (removemos saltos de línea)
lines = [line.strip() for line in lines]

# Dividimos las líneas en grupos de 3
data = []
for i in range(0, len(lines), 3):
    id_item = lines[i]
    nombre_item = lines[i+1]
    count = lines[i+2]
    data.append([id_item, nombre_item, count])

# Convertimos a DataFrame
items = pd.DataFrame(data, columns=['id_item', 'nombre_item', 'count'])
items
# Out:
#     id_item                             nombre_item count
# 0     17365      Casa de las Rocas-Museo del Corpus    11
# 1     17366                    Casa-Museo Benlliure    11
# 2     17367                Casa-Museo Blasco Ibañez    11
# 3     17369       Centro cultural Fundación Bancaja    30
# 4     17371                  Centro del Carmen-IVAM    26
# ..      ...                                     ...   ...
# 145   18002                        Barrio de Ruzafa     0
# 146   18003                             La Albufera     0
# 147   18004                      Barrio del Cabañal     0
# 148   18005                          Museo Iluziona     0
# 149   18006  L'ETNO - Museo Valenciado de Etnología     0
#
# [150 rows x 3 columns]

# %%
import pandas as pd

# Suponiendo que el archivo se llama "datos.txt"
with open("rawdata/clasificacion_items.txt", "r", encoding="latin-1") as file:
    # Leemos todas las líneas del archivo
    lines = file.readlines()

# Limpiamos las líneas (removemos saltos de línea)
lines = [line.strip() for line in lines]

# Dividimos las líneas en grupos de 3
data = []
for i in range(0, len(lines), 3):
    id_item = lines[i]
    nombre_item = lines[i+1]
    count = lines[i+2]
    data.append([id_item, nombre_item, count])

# Convertimos a DataFrame
class_items = pd.DataFrame(data, columns=['id_item', 'id_categoria', 'adec'])
class_items
# Out:
#     id_item id_categoria adec
# 0     17365           65   61
# 1     17365           68   67
# 2     17366           62   78
# 3     17366           68   75
# 4     17367           26   20
# ..      ...          ...  ...
# 378   18004          115   80
# 379   18005           68   80
# 380   18005           14   80
# 381   18006           68   80
# 382   18006           14   60
#
# [383 rows x 3 columns]

# %%
items_merged = pd.merge(items, class_items, on='id_item', how='inner')
items_merged
# Out:
#     id_item                             nombre_item count id_categoria adec
# 0     17365      Casa de las Rocas-Museo del Corpus    11           65   61
# 1     17365      Casa de las Rocas-Museo del Corpus    11           68   67
# 2     17366                    Casa-Museo Benlliure    11           62   78
# 3     17366                    Casa-Museo Benlliure    11           68   75
# 4     17367                Casa-Museo Blasco Ibañez    11           26   20
# ..      ...                                     ...   ...          ...  ...
# 378   18004                      Barrio del Cabañal     0          115   80
# 379   18005                          Museo Iluziona     0           68   80
# 380   18005                          Museo Iluziona     0           14   80
# 381   18006  L'ETNO - Museo Valenciado de Etnología     0           68   80
# 382   18006  L'ETNO - Museo Valenciado de Etnología     0           14   60
#
# [383 rows x 5 columns]

# %%
import pandas as pd

# Suponiendo que el archivo se llama "datos.txt"
with open("rawdata/preferencias.txt", "r", encoding="latin-1") as file:
    # Leemos todas las líneas del archivo
    lines = file.readlines()

# Limpiamos las líneas (removemos saltos de línea)
lines = [line.strip() for line in lines]

# Dividimos las líneas en grupos de 3
data = []
for i in range(0, len(lines), 3):
    id_item = lines[i]
    nombre_item = lines[i+1]
    count = lines[i+2]
    data.append([id_item, nombre_item, count])

# Convertimos a DataFrame
preferencias = pd.DataFrame(data, columns=['id_categoria', 'descripcion', 'padre'])
preferencias
# Out:
#     id_categoria                   descripcion padre
# 0              1            Estilos y periodos     0
# 1              2                       Compras     0
# 2              3                        Museos     0
# 3              4             Espacios Abiertos     0
# 4              5        Arquitectura religiosa     0
# ..           ...                           ...   ...
# 110          111  Otras arquitectura religiosa     5
# 111          112                 Otros eventos    13
# 112          113             Otros gastronomía     8
# 113          114                    Otros ocio    11
# 114          115                 Otros estilos     1
#
# [115 rows x 3 columns]

# %%
items_merged2 = pd.merge(items_merged, preferencias, on='id_categoria', how='inner')
items_merged2 = items_merged2.rename(columns={"padre": "id_padre"})
items_merged2
# Out:
#     id_item                             nombre_item count id_categoria adec  \
# 0     17365      Casa de las Rocas-Museo del Corpus    11           65   61
# 1     17365      Casa de las Rocas-Museo del Corpus    11           68   67
# 2     17366                    Casa-Museo Benlliure    11           62   78
# 3     17366                    Casa-Museo Benlliure    11           68   75
# 4     17367                Casa-Museo Blasco Ibañez    11           26   20
# ..      ...                                     ...   ...          ...  ...
# 378   18004                      Barrio del Cabañal     0          115   80
# 379   18005                          Museo Iluziona     0           68   80
# 380   18005                          Museo Iluziona     0           14   80
# 381   18006  L'ETNO - Museo Valenciado de Etnología     0           68   80
# 382   18006  L'ETNO - Museo Valenciado de Etnología     0           14   60
#
#                   descripcion id_padre
# ...

# %%
preferencias_padre = preferencias.rename(columns={"id_categoria": "id_padre", "descripcion": "padre_descripcion"})
preferencias_padre
# Out:
#     id_padre             padre_descripcion padre
# 0          1            Estilos y periodos     0
# 1          2                       Compras     0
# 2          3                        Museos     0
# 3          4             Espacios Abiertos     0
# 4          5        Arquitectura religiosa     0
# ..       ...                           ...   ...
# 110      111  Otras arquitectura religiosa     5
# 111      112                 Otros eventos    13
# 112      113             Otros gastronomía     8
# 113      114                    Otros ocio    11
# 114      115                 Otros estilos     1
#
# [115 rows x 3 columns]

# %%
items_final = pd.merge(items_merged2, preferencias_padre, on='id_padre', how='inner')
items_final
# Out:
#     id_item                             nombre_item count id_categoria adec  \
# 0     17365      Casa de las Rocas-Museo del Corpus    11           65   61
# 1     17365      Casa de las Rocas-Museo del Corpus    11           68   67
# 2     17366                    Casa-Museo Benlliure    11           62   78
# 3     17366                    Casa-Museo Benlliure    11           68   75
# 4     17367                Casa-Museo Blasco Ibañez    11           26   20
# ..      ...                                     ...   ...          ...  ...
# 356   18004                      Barrio del Cabañal     0           41   80
# 357   18004                      Barrio del Cabañal     0           48   50
# 358   18004                      Barrio del Cabañal     0          115   80
# 359   18005                          Museo Iluziona     0           68   80
# 360   18006  L'ETNO - Museo Valenciado de Etnología     0           68   80
#
# ...

# %%
preferencias_padre.to_csv('data/items.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 preferencias_padre.to_csv('data/items.csv', index=False)
#
# File ~/miniconda3/envs/rna1/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
